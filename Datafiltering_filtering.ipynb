# %%
import pandas as pd
df = pd.read_csv("my_data.csv")
df
# Out:
#                                                                                       1745500125912-data (1)
# Actor              Film                     Year Genre           BoxOffice(INR Crore)                   IMDb
# Shah Rukh Khan     Pathaan                  2023 Action          1050                                    7.2
# Salman Khan        Tiger Zinda Hai          2017 Action          565                                     6.0
# Aamir Khan         Dangal                   2016 Biography       2024                                    8.4
# Ranbir Kapoor      Brahmastra               2022 Fantasy         431                                     5.6
# Ranveer Singh      Padmaavat                2018 Historical      585                                     7.0
# Ayushmann Khurrana Andhadhun                2018 Thriller        111                                     8.3
# Rajkummar Rao      Stree                    2018 Horror Comedy   180                                     7.5
# ...
