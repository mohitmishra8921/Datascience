# %%
import pandas as pd
df = pd.read_excel("my_data.xlsx")
df
# Out:
#    1745500125912-data (1)                Unnamed: 1 Unnamed: 2  \
# 0                   Actor                      Film       Year
# 1          Shah Rukh Khan                   Pathaan       2023
# 2             Salman Khan           Tiger Zinda Hai       2017
# 3              Aamir Khan                    Dangal       2016
# 4           Ranbir Kapoor                Brahmastra       2022
# 5           Ranveer Singh                 Padmaavat       2018
# 6      Ayushmann Khurrana                 Andhadhun       2018
# 7           Rajkummar Rao                     Stree       2018
# 8          Hrithik Roshan                       War       2019
# 9            Akshay Kumar                Good Newwz       2019
# 10          Kartik Aaryan         Bhool Bhulaiyaa 2       2022
# 11           Varun Dhawan     Badrinath Ki Dulhania       2017
# 12          Vicky Kaushal  Uri: The Surgical Strike       2019
#
#          Unnamed: 3            Unnamed: 4 Unnamed: 5
# ...

# %% [markdown]
# # Data selection

# %%
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.loc[0]
#
# ...
