# %%
import numpy as np
arr = np.array([23,45,37,89])

# %%
arr
# Out:
# array([23, 45, 37, 89])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
import numpy as np
arr2 = np.array([23,45,37,89],"int32")

# %%
arr2
# Out:
# array([23, 45, 37, 89], dtype=int32)

# %%
arr2.dtype
# Out:
# dtype('int32')

# %%
arr.nbytes #to check how memory they all store
# Out:
# 32

# %%
arr2.nbytes
# Out:
# 16

# %%
arr3 = np.array([1 + 2j, 3 + 4j, 5 + 6j], dtype='complex128') 
print(arr)
# Out:
# [23 45 37 89]

# %%
arr3.nbytes
# Out:
# 48

# %%
arr4 = np.array([1 + 2j, 3 + 4j, 5 + 6j], dtype='complex64')#Downcasting
print(arr)
# Out:
# [23 45 37 89]

# %%
arr4.nbytes
# Out:
# 24
