# %%
import numpy as np
arr = np.array([2,3,4,5])
mean = np.mean(arr)
print(mean )
# Out:
# 3.5

# %%
import numpy as np 
arr = np.array([20,30,40,50])
std = np.std(arr)
print(std)
# Out:
# 11.180339887498949

# %%
import numpy as np 
arr = np.array([3,4,5,6,7])
var = np.var(arr)
print(var)
# Out:
# 2.0

# %%
import numpy as np
arr = np.array([3,4,5,6,7])
minimum = np.min(arr)
print(minimum)
# Out:
# 3

# %%
import numpy as np 
arr = np.array([1,2,3,4,5])
maximum = np.max(arr)
print(maximum)
# Out:
# 5

# %%
import numpy as np
arr = np.array([1,2,3,4,5])
addition = np.sum(arr)
print(addition)
# Out:
# 15

# %%
import numpy as np
arr = np.array([1,2,3,4,5])
product = np.prod(arr)
print(product)
# Out:
# 120

# %%
import numpy as np
arr = np.array([1,2,3,4,5])
median = np.median(arr)
print(median)
# Out:
# 3.0

# %%
import numpy as np
arr = np.array([100,99,98,97,96])
percentile = np.percentile(arr,50)
print(percentile)
# Out:
# 98.0

# %%
import numpy as np
arr = np.array([1,0,3,4,5])
min_index = np.argmin(arr)
print(min_index)
# Out:
# 1

# %%
import numpy as np
arr = np.array([1,0,3,4,5])
max_index = np.argmax(arr)
print(max_index)
# Out:
# 4

# %%
import numpy as np
arr = np.array([1,0,3,4,5])
corrcoef = np.corrcoef(arr)
print(corrcoef)
# Out:
# 1.0

# %%
np.unique(arr)
