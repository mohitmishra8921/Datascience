# %%
# !pip install pandas

# %%
import pandas as pd 
data = pd.Series([1,2,3,4,5],index=["a","b","c","d","e"])
data
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data = {
"Name": ["Alice", "Bob", "Charlie","Alice", "Bob", "Charlie","Alice", "Bob", "Charlie","Alice", "Bob", "Charlie"],
"Age": [25, 30, 35,25, 30, 35,25, 30, 35,25, 30, 35],
"City": ["Delhi", "Mumbai", "Bangalore","Delhi", "Mumbai", "Bangalore","Delhi", "Mumbai", "Bangalore","Delhi", "Mumbai", "Bangalore"],
"Names": ["Alice", "Bob", "Charlie","Alice", "Bob", "Charlie","Alice", "Bob", "Charlie","Alice", "Bob", "Charlie"],
"Ages": [25, 30, 35,25, 30, 35,25, 30, 35,25, 30, 35],
"Cities": ["Delhi", "Mumbai", "Bangalore","Delhi", "Mumbai", "Bangalore","Delhi", "Mumbai", "Bangalore","Delhi", "Mumbai", "Bangalore"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age       City    Names  Ages     Cities
# 0     Alice   25      Delhi    Alice    25      Delhi
# 1       Bob   30     Mumbai      Bob    30     Mumbai
# 2   Charlie   35  Bangalore  Charlie    35  Bangalore
# 3     Alice   25      Delhi    Alice    25      Delhi
# 4       Bob   30     Mumbai      Bob    30     Mumbai
# 5   Charlie   35  Bangalore  Charlie    35  Bangalore
# 6     Alice   25      Delhi    Alice    25      Delhi
# 7       Bob   30     Mumbai      Bob    30     Mumbai
# 8   Charlie   35  Bangalore  Charlie    35  Bangalore
# 9     Alice   25      Delhi    Alice    25      Delhi
# 10      Bob   30     Mumbai      Bob    30     Mumbai
# 11  Charlie   35  Bangalore  Charlie    35  Bangalore
