# %%
import pandas as pd
from bs4 import BeautifulSoup 
import requests
item = []
with open("html/page1.html" ) as f:
    content = f.read()
soup = BeautifulSoup(content,"html.parser")
a = soup.h1.text
item.append(a)
print(item)
# Out:
# ['All products']

# %%
pd.DataFrame(item,columns =["Products"])
# Out:
#        Products
# 0  All products
