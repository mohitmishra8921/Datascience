# %%
import matplotlib.pyplot as plt 
plt.plot([2,3,4],[2,5,8])

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.plot(years, runs)

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.plot(years, runs)

plt.xlabel("years➡️")
plt.ylabel("Runs")
plt.title("Runs of Sachin Tendulkar")
# Out:
# Text(0.5, 1.0, 'Runs of Sachin Tendulkar')

# %%
import matplotlib.pyplot as plt 
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
plt.plot(years,kohli,color="green",linestyle ="--",label = "Virat Kohli")
plt.plot(years,sehwag,color="black",linestyle =":",label = "Sehwag")
plt.xlabel("years")
plt.ylabel("Runs")
plt.grid()
plt.tight_layout()
plt.title("Performance analysis")
plt.legend()
