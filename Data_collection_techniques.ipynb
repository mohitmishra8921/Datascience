# %% [markdown]
# # DATA COLLECTION TECHNIQUES
# FIRST COLLECT DATA ACCORDING TO THE REQUIREMENT OF DATA
#
# ALWAYS MAKE CLEAR THPUGHT ABOUT DATA BECAUSE OUR MODEL FLUENCY DEPENDS ON TYPE OF DATA USEFUL DATA BUILD BEST MODEL
#
# ALWAYS KEPT IN MIND COLLECT DATA THROUGH LEGAL SOURCES
#
# TAKE PERMISSIONS FOR USAGE OF OTHERS DATA WITH SHOUTOUTS TO THEM
#
# ALWAYS COLLECT EFFICIENT DATA FOR MODEL AND USE BEST TOOLS FOR MODEL TO BUILD IT AS ADVANCED MODELS
