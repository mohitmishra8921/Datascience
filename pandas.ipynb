# %%
import pandas as pd

# %%
series = pd.Series([1,2,3,4,5,])
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
dataframe = pd.DataFrame([1,2,3,4,5])
print(dataframe)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
marks = pd.Series([98,99,89,97,94],index =["Harry","Mohit","Mohan","Rajeev","Shukla"])
print(marks)
# Out:
# Harry     98
# Mohit     99
# Mohan     89
# Rajeev    97
# Shukla    94
# dtype: int64

# %%
print(marks["Harry"])
# Out:
# 98

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='str')
